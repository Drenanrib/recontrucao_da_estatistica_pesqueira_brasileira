MB/s eta 0:00:00
# Using cached termcolor-2.4.0-py3-none-any.whl (7.7 kB)
# Using cached tensorboard_data_server-0.7.2-py3-none-any.whl (2.4 kB)
# Downloading dm_tree-0.1.8-cp311-cp311-win_amd64.whl (101 kB)
#    ---------------------------------------- 0.0/101.3 kB ? eta -:--:--
#    ---------------------------------------- 101.3/101.3 kB ? eta 0:00:00
# Using cached namex-0.0.7-py3-none-any.whl (5.8 kB)
# Installing collected packages: namex, libclang, flatbuffers, dm-tree, termcolor, tensorflow-io-gcs-filesystem, tensorboard-data-server, opt-einsum, ml-dtypes, h5py, grpcio, google-pasta, gast, astunparse, absl-py, tensorboard, keras, tensorflow-intel, tensorflow
#   Attempting uninstall: h5py
#     Found existing installation: h5py 3.9.0
#     Uninstalling h5py-3.9.0:
#       Successfully uninstalled h5py-3.9.0
# Successfully installed absl-py-2.1.0 astunparse-1.6.3 dm-tree-0.1.8 flatbuffers-24.3.7 gast-0.5.4 google-pasta-0.2.0 grpcio-1.62.1 h5py-3.10.0 keras-3.0.5 libclang-16.0.6 ml-dtypes-0.3.2 namex-0.0.7 opt-einsum-3.3.0 tensorboard-2.16.2 tensorboard-data-server-0.7.2 tensorflow-2.16.1 tensorflow-intel-2.16.1 tensorflow-io-gcs-filesystem-0.31.0 termcolor-2.4.0

# %%
import pandas as pd
import matplotlib.pyplot as plt
from openpyxl import workbook
import numpy as np
import tensorflow as tf

# %%
data = pd.read_excel('reconstrucao_estatistica_brasileira\Data_sets\qReconstrucaoDoceMarinho22122023 (1).xlsx')
print(data)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 data = pd.read_excel('reconstrucao_estatistica_brasileira\Data_sets\qReconstrucaoDoceMarinho22122023 (1).xlsx')
#       2 print(data)
#
# NameError: name 'pd' is not defined

# %%
remocao = (data['Habitat'] == 'Marinho')
df = data[remocao]
print(df)
df_1 = pd.DataFrame({
    'Estado': df['Estado'],
    'Ano': data['Ano'],
    'Nome': data['NomeComum'],
    'Tipo': data['Tipo'],
    'Captura': data['Captura']})
#df_1.to_csv('reconstrucao_estatistica_brasileira\Data_sets\Extraidos/df1.csv')
print(df_1)
# Out:
#                Estado   Ano  NomeComum  Captura           Tipo  \
# 0             Sergipe  1980     Sururu      1.0      Artisanal
# 1             Sergipe  1982     Sururu      2.0      Artisanal
# 2             Sergipe  1983     Sururu      5.0      Artisanal
# 3             Sergipe  1984     Sururu      4.0      Artisanal
# 4             Sergipe  1985     Sururu      8.0      Artisanal
# ...               ...   ...        ...      ...            ...
# 40583  Santa Catarina  1968     Baleia     15.0  Not specified
# 40584  Santa Catarina  1973  Quelônios     31.0  Not specified
# 40585  Santa Catarina  1974  Quelônios      3.0  Not specified
# 40586  Santa Catarina  1975  Quelônios      1.0  Not specified
# 40587  Santa Catarina  1976  Quelônios      2.0  Not specified
#
#                      Fonte  Habitat
# 0             IBGE (1983a)  Marinho
# 1       IBGE (1983d,1984a)  Marinho
# 2       IBGE (1984b,1985a)  Marinho
# 3           IBGE (1985b,c)  Marinho
# 4        IBGE (1986,1987a)  Marinho
# ...                    ...      ...
# 40583       MA/ETEA (1969)  Marinho
# 40584  SUDEPE/IBGE (1976a)  Marinho
# 40585  SUDEPE/IBGE (1976b)  Marinho
# 40586        SUDEPE (1977)  Marinho
# 40587  SUDEPE/IBGE (1979a)  Marinho
#
# [40588 rows x 7 columns]
#         Estado   Ano      Nome       Tipo  Captura
# 0      Sergipe  1980    Sururu  Artisanal      1.0
# 1      Sergipe  1982    Sururu  Artisanal      2.0
# 2      Sergipe  1983    Sururu  Artisanal      5.0
# 3      Sergipe  1984    Sururu  Artisanal      4.0
# 4      Sergipe  1985    Sururu  Artisanal      8.0
# ...        ...   ...       ...        ...      ...
# 47782      NaN  2007    Outros  Artisanal      6.0
# 47783      NaN  2007   Tamoatá  Artisanal      1.0
# 47784      NaN  2007   Tilápia  Artisanal    161.5
# 47785      NaN  2007    Traíra  Artisanal      5.5
# 47786      NaN  2007  Tucunaré  Artisanal      7.5
#
# [47787 rows x 5 columns]

# %%
especies= set(df_1['Nome'])
print(especies)
especies_list= list
# Out:
# {'Truta', 'Tubajara', 'Serrão', 'Cacunda', 'Cascuda', 'Chaveta', 'Tracajá', 'Cavala', 'Camarão barba ruça', 'Bagre (Africano)', 'Branquinha (Beiru)', 'Albacora bandolim', 'Lagosta sapateira', 'Oriocó', 'Coró', 'Matrinchã', 'Dentão', 'Caranguejo vermelho', 'Pititinga', 'Pescada do Piauí', 'Catana', 'Arabaiana', 'Agulha preta', 'Pena', 'Ubarana', 'Pescadinha', 'Cação toninha', 'Cação bagre', 'Jaú', 'Corcoroca', 'Coroque', 'Machote', 'Batera', 'Cachara', 'Caranha', 'Tartaruga', 'Camarão', 'Aratu', 'Abrótea', 'Tucunaré', 'Guaricema', 'Carapicu', 'Bonito cachorro', 'Pacamon', 'Tainha', 'Pacu', 'Pacamão', 'Tainhota', 'Voador', 'Peixe frade', 'Corvina', 'Uricica', 'Albacora', 'Bandeirado', 'Lambari', 'Tambaqui', 'Piracanjuba', 'Salgo', 'Miragaia', 'Tapa pomba', 'Piranha', 'Lírio', 'Papagaio', 'Gurijuba', 'Carrapato', 'Peixe-rei', 'Cubiu', 'Agulhão branco', 'Caranguejo (mar)', 'Maromba', 'Pirambeba', 'Cambeba', 'Carapitanga', 'Oriacica', 'Cação raposa', 'Sardinha cascuda', 'Anjo', 'Apaiari', 'Congro rosa', 'Caranguejo de profundidade', 'Muzundu', 'Cação viola', 'Gato', 'Cuiú-cuiú', 'Peixe-espada', 'Soia', 'Lua', 'Pescada bicuda', 'Agulha branca', 'Camarão santana', 'Saberé', 'Ariacó', 'Moluscos não identificados', 'Pampo', 'Ubaria', 'Cação bico doce', 'Peixes não identificados', 'Tararaca', 'Unha de velho', 'Catuá', 'Carataí', 'Cação lombo preto', 'Xangó', 'Carpa', 'Catuá (garoupinha)', 'Saramonete', 'Manjubão', 'Xira', 'Canguira', 'Black-bass', 'Sardinha verdadeira', 'Olhete', 'Enxova', 'Parati olho de fogo', 'Caranguejo uçá', 'Panaguau', 'Lagosta (de mar)', 'Dourada', 'Pescada gó', 'Concha', 'Parati', 'Pirarara', 'Pescada-branca', 'Caraúna', 'Paru 2', 'Aruanã', 'Agulhão de vela', 'Vivoca', 'Bagrinho', 'Cações (outras espécies)', 'Bonito pintado', 'Gordinho (paru)', 'Peixe-cachorro', 'Peroá', 'Mandubé', 'Outros', 'Peixe espada', 'Viola', 'Graçainha', 'Curimatã', 'Pirapitinga', 'Peixe voador', 'Camarão alistado', 'Capado', 'Cação cabeça chata', 'Piába', 'Cação', 'Camarão sete barbas', 'Crustáceos não especificados', 'Cambira', 'Moluscos', 'Trilha', 'Pirambiju', 'Brota', 'Cará', 'Piraiba', 'Judeu', 'Pescada vermelha', 'Garassuma', 'Sardinha boca torta', 'Manjuba', 'Papa terra (betara)', 'Sardinha bandeira', 'Mira céu', 'Congro', 'Bonito barriga lisa', 'Guaiamum', 'Outros crustáceos', 'Bonito listrado', 'Tamatarana', 'Pratibu', 'Mirucaia', 'Acará', 'Curimbatá', 'Uritinga', 'Aracu', 'Barbudo', 'Pirucaia', 'Caçonete', 'Graviola', 'Jacundá', 'Cação anjo', 'Tambicu', 'Cherne', 'Caíca', 'Calamar argentino', 'Maçunim', 'Peixe porco', 'Gordinho', 'Matrinxã', 'Piraúna', 'Galo de profundidade', 'Peixe galo', 'Bom nome', 'Mamíferos aquáticos', 'Mulata (vermelho)', 'Croaçu', 'Trombeta', 'Goete', 'Marisco', 'Michole', 'Avoador', 'Albacora branca', 'Branquinha', 'Peixes de água doce não identificados', 'Ituí', 'Outros carangídeos', 'Serra', 'Sardinha laje', 'Olhuda', 'Moluscos não especificados', 'Guaracema', 'Cação panam', 'Peixe espada (de mar)', 'Pescada olhuda', 'Piramutaba', 'Mapará', 'Savelha (sabelha)', 'Pescadinha gó', 'Enguia', 'Taguara', 'Merete', 'Solteira (guaivira)', 'Cambuba', 'Caranguejo', 'Jaraqui', 'Arraia', 'Pescada verdadeira', 'Bacalhau', 'Cachorro', 'Bocudo', 'Lambreta', 'Galo', 'Emplastro', 'Golosa', 'Garoupa', 'Piavuçu', 'Camarão-canela', 'Pescada cambuçu', 'Cação tigre', 'Serrinha', 'Curuca', 'Mexilhão', 'Urubara', 'Boca mole', 'Cururuca', 'Cabrinha', 'Solteira', 'Lagosta', 'Acaratinga', 'Camorim', 'Anchoveta', 'Realito', 'Robalo', 'Budião', 'Savelha', 'Marlin', 'Pescadas (outras espécies)', 'Tinga', 'Redondo', 'Maria luíza', 'Peixe agulha', 'Albacora laje', 'Papaterra', 'Baiacu de espinho', 'Biru', 'Garaximbora', 'Papa terra', 'Pacumão', 'Saúba', 'Sambuio', 'Sapateiro', 'Baiacu guara', 'Batata', 'Gó', 'Tortinha', 'Cabeçudo', 'Cação anequim', 'Rabo de fogo', 'Bagre (Mandi)', 'Guaibira', 'Cachorra', 'Bicuda', 'Caica', 'Cação cavala', 'Camarão legítimo', 'Cação espadarte', 'Albacora (atum)', 'Aracaroba', 'Aracanguira', 'Carapeb ...

# %%
selecao1 = (df_1['Estado'] == 'Sergipe') & (df_1['Nome'] == 'Camarão (de mar)') #& (df_1['Tipo'] == 'Artesanal')
df= df_1[selecao1]
df.to_csv('reconstrucao_estatistica_brasileira\Data_sets\Extraidos\Sergipe_Bagre.csv')

# %%
x0 = []
x1 = []
x2 = []

x = list(df['Ano'])
y = list(df['Captura'])
z = list(df['Tipo'])
print(x,y,z)

for i,ano in enumerate(x):
    tipo = z[i]
    capt = y[i]

    if (tipo == 'Artisanal'):
        x1.append([ano,capt])
    elif (tipo == 'Industrial'):
        x2.append([ano,capt])
    else:
        x0.append([ano,capt])


x1 = np.array(x1)
x2= np.array(x2)
x0 = np.array(x0)
plt.scatter(x1[:,0], x1[:,1], c='b')
plt.scatter(x2[:,0], x2[:,1], c='r')
#plt.scatter(x0[:,0], x0[:,1], c='g')
plt.show()
# Out:
# [1962, 1963, 1964, 1966, 1967, 1968, 1969, 1971, 1972, 1973, 1974, 1975, 1976, 1977, 1978, 1979, 1980, 1981, 1982, 1983, 1984, 1985, 1986, 1987, 1988, 1989, 1990, 1991, 1992, 1993, 1994, 1995, 1981, 1982, 1983, 1984, 1985, 1986, 1987, 1988, 1989, 1990, 1991, 1992, 1993, 1994] [49.0, 67.0, 59.0, 56.0, 56.0, 60.0, 52.0, 54.0, 51.0, 49.0, 114.0, 74.0, 34.0, 57.0, 63.0, 28.0, 94.0, 120.0, 164.0, 178.0, 189.0, 283.0, 309.0, 190.0, 223.0, 176.0, 303.0, 324.0, 379.0, 303.0, 433.5, 1454.0, 58.0, 48.0, 770.0, 772.0, 740.0, 458.0, 1232.0, 869.0, 684.0, 682.0, 729.0, 851.0, 682.0, 976.5] ['Not specified', 'Not specified', 'Not specified', 'Not specified', 'Not specified', 'Not specified', 'Not specified', 'Not specified', 'Not specified', 'Not specified', 'Not specified', 'Not specified', 'Not specified', 'Not specified', 'Artisanal', 'Artisanal', 'Artisanal', 'Artisanal', 'Artisanal', 'Artisanal', 'Artisanal', 'Artisanal', 'Artisanal', 'Artisanal', 'Artisanal', 'Artisanal', 'Artisanal', 'Artisanal', 'Artisanal', 'Artisanal', 'Artisanal', 'Artisanal', 'Industrial', 'Industrial', 'Industrial', 'Industrial', 'Industrial', 'Industrial', 'Industrial', 'Industrial', 'Industrial', 'Industrial', 'Industrial', 'Industrial', 'Industrial', 'Industrial']

# %%
nA = len(x1)
nI = len(x2)
num = max([nA,nI])


ano_min = min([np.min(x1[:,0]),np.min(x2[:,0])])


ano_max = max([np.max(x1[:,0]),np.max(x2[:,0])])

list_ano = range(int(ano_min), int(ano_max + 1))

n = len(list_ano)


soma = np.zeros((n, 2))

# %%
import numpy as np

nA = len(x1)
nI = len(x2)
num = max(nA, nI)

ano_min = min(np.min(x1[:,0]), np.min(x2[:,0]))
ano_max = max(np.max(x1[:,0]), np.max(x2[:,0]))

list_ano = range(int(ano_min), int(ano_max + 1))
n = len(list_ano)

soma = np.zeros((n, 2))

for i, ano in enumerate(list_ano):
    if ano in x1[:,0] and ano in x2[:,0]:
        idx1 = np.where(x1[:,0] == ano)[0][0]
        idx2 = np.where(x2[:,0] == ano)[0][0]
        soma[i,:] = [ano, x1[idx1,1] + x2[idx2,1]]


    elif ano in x1[:,0] and ano not in x2[:,0]:
        idx1 = np.where(x1[:,0] == ano)[0][0]
        soma[i,:] = [ano, x1[idx1,1]]
        print("1")

    elif ano in x2[:,0] and ano not in x1[:,0]:
        idx2 = np.where(x2[:,0] == ano)[0][0]
        soma[i,:] = [ano, x2[idx2,1]]
        print("2")
    else:
        print('Ano não cadastrado')
# Out:
# 1
# 1
# 1
# 1

# %%
df_x1 = pd.DataFrame(x1, columns=['Ano', 'Captura']) #Artesanal
df_x2 = pd.DataFrame(x2, columns=['Ano', 'Captura']) #Industrial
df_x0 = pd.DataFrame(x0, columns=['Ano', 'Captura']) #Não especificado

# %%
print(df_x1)
print(df_x2)
print(print(df_x0))
# Out:
#        Ano  Captura
# 0   1978.0     63.0
# 1   1979.0     28.0
# 2   1980.0     94.0
# 3   1981.0    120.0
# 4   1982.0    164.0
# 5   1983.0    178.0
# 6   1984.0    189.0
# 7   1985.0    283.0
# 8   1986.0    309.0
# 9   1987.0    190.0
# 10  1988.0    223.0
# 11  1989.0    176.0
# 12  1990.0    303.0
# 13  1991.0    324.0
# 14  1992.0    379.0
# 15  1993.0    303.0
# 16  1994.0    433.5
# 17  1995.0   1454.0
#        Ano  Captura
# 0   1981.0     58.0
# 1   1982.0     48.0
# 2   1983.0    770.0
# 3   1984.0    772.0
# 4   1985.0    740.0
# 5   1986.0    458.0
# 6   1987.0   1232.0
# 7   1988.0    869.0
# 8   1989.0    684.0
# 9   1990.0    682.0
# 10  1991.0    729.0
# 11  1992.0    851.0
# 12  1993.0    682.0
# 13  1994.0    976.5
#        Ano  Captura
# 0   1962.0     49.0
# 1   1963.0     67.0
# 2   1964.0     59.0
# 3   1966.0     56.0
# 4   1967.0     56.0
# 5   1968.0     60.0
# 6   1969.0     52.0
# 7   1971.0     54.0
# 8   1972.0     51.0
# 9   1973.0     49.0
# 10  1974.0    114.0
# 11  1975.0     74.0
# 12  1976.0     34.0
# 13  1977.0     57.0
# None

# %%
df_x1=df_x1.drop_duplicates(subset='Captura')
print(df_x1)
# Out:
#      Ano  Captura
# 0   1978     63.0
# 1   1979     28.0
# 2   1980     94.0
# 3   1981    120.0
# 4   1982    164.0
# 5   1983    178.0
# 6   1984    189.0
# 7   1985    283.0
# 8   1986    309.0
# 9   1987    190.0
# 10  1988    223.0
# 11  1989    176.0
# 12  1990    303.0
# 13  1991    324.0
# 14  1992    379.0
# 16  1994    433.5
# 17  1995   1454.0

# %%
x = np.array(df_x1['Ano'], dtype=np.float32).reshape(-1, 1)
y = np.array(df_x1['Captura'], dtype=np.float32).reshape(-1, 1)


x_mean = np.mean(x)
x_std = np.std(x)
x_normalized = (x - x_mean) / x_std

y_mean = np.mean(y)
y_std = np.std(y)
y_normalized = (y - y_mean) / y_std


model = tf.keras.Sequential([
    tf.keras.layers.Dense(128, activation='leaky_relu', input_shape=(1,)),
    tf.keras.layers.Dense(64, activation='leaky_relu'),
    tf.keras.layers.Dense(32, activation='leaky_relu'),
    tf.keras.layers.Dense(1, activation='leaky_relu')

])


opt = tf.keras.optimizers.Adam(learning_rate=0.01)  # Learning rate = 0.01
model.compile(optimizer=opt, loss='mse', metrics=['accuracy'])


history = model.fit(x_normalized, y_normalized, epochs=400, verbose=0)


plt.scatter(x_normalized, y_normalized, color='blue', label='Dados originais')
plt.xlabel('Ano')
plt.ylabel('Captura')
plt.title('Predição')
plt.plot(x_normalized, model.predict(x_normalized), color='red', label='Predição')
plt.legend()
plt.show()


loss_values = history.history['loss']
accuracy_values = history.history['accuracy']

epochs = range(1, len(loss_values) + 1)

plt.figure(figsize=(12, 6))

# Plotando a perda
plt.subplot(1, 2, 1)
plt.plot(epochs, loss_values, 'b')
plt.xlabel('Épocas')
plt.ylabel('Loss')
plt.title('Loss ao longo das épocas')
# Out:
# c:\Users\Renan\anaconda3\Lib\site-packages\keras\src\layers\core\dense.py:85: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# Text(0.5, 1.0, 'Loss ao longo das épocas')

# %%
x = np.array(df_x2['Ano'], dtype=np.float32).reshape(-1, 1)
y = np.array(df_x2['Captura'], dtype=np.float32).reshape(-1, 1)

# Normalizando os dados
x_mean = np.mean(x)
x_std = np.std(x)
x_normalized = (x - x_mean) / x_std

y_mean = np.mean(y)
y_std = np.std(y)
y_normalized = (y - y_mean) / y_std

# Construindo o modelo
model = tf.keras.Sequential([
    tf.keras.layers.Dense(128, activation='elu', input_shape=(1,)),
    tf.keras.layers.Dense(64, activation='elu'),
    tf.keras.layers.Dense(32, activation='elu'),
    tf.keras.layers.Dense(16, activation='elu'),
    tf.keras.layers.Dense(1, activation='elu')

])

# Compilando o modelo
opt = tf.keras.optimizers.Adam(learning_rate=0.01)  # Learning rate = 0.01
model.compile(optimizer=opt, loss='mse', metrics=['accuracy'])

# Treinando o modelo
history = model.fit(x_normalized, y_normalized, epochs=400, verbose=0)

# Plotando a predição
plt.scatter(x_normalized, y_normalized, color='blue', label='Dados originais')
plt.xlabel('Ano')
plt.ylabel('Captura')
plt.title('Predição')
plt.plot(x_normalized, model.predict(x_normalized), color='red', label='Predição')
plt.legend()
plt.show()

# Plotando a perda e a acurácia ao longo das épocas
loss_values = history.history['loss']
accuracy_values = history.history['accuracy']

epochs = range(1, len(loss_values) + 1)

plt.figure(figsize=(12, 6))

# Plotando a perda
plt.subplot(1, 2, 1)
plt.plot(epochs, loss_values, 'b')
plt.xlabel('Épocas')
plt.ylabel('Loss')
plt.title('Loss ao longo das épocas')
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# Text(0.5, 1.0, 'Loss ao longo das épocas')

# %%
model.save('model_architecture.h5')
model.save_weights('model_weights.h5')
